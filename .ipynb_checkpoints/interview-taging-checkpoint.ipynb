# %%
import pandas as pd
import itertools
import altair as alt
import seaborn as sns
from IPython.core.display_functions import display
from kmodes.kmodes import KModes
pd.options.mode.chained_assignment = None  # default='warn'
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("G2_ User Interview - Final - User Interviews.csv", index_col="name")
data
# Out:
#           interviewer  Q age age ranks  \
# name
# Sabine            Ina     54       >40
# Jenny             Ina     30     21-30
# Britta            Ina     33     31-40
# Lisa              Ina     29     21-30
# Jaqueline         Ina     25     21-30
# Cristina    Christine     38     31-40
# Stephan     Christine     28     21-30
# Petra       Christine     59       >40
# Matic            Ziga     29     21-30
# Natalija         Ziga     29     21-30
# Primož           Ziga     29     21-30
# Nastja           Ziga     26     21-30
# Börni           Noemi     25     21-30
# Tereza          Noemi     24     21-30
# Nico            Noemi     30     21-30
# Volker            Jos     43       >40
# Theresa           Jos     43       >40
# Maria             Jos     48       >40
# Sofia          Pietro     22     21-30
# Emma           Pietro     21     21-30
# Lorenzo        Pietro     23     21-30
# Rocco          Pietro     24     21-30
#
#                     Q background: work / study, relationship  \
# name
# Sabine                 Draftswers, Industrial clerk\nmarried
# Jenny       Graphic Designer, Freelancer,\nin a relationship
# Britta     studied Interior Architecture, Design & Produk...
# Lisa       Master, working as Retail Marketing Manager\ni...
# Jaqueline  Master Restaurierung / Konservierung für Papie...
# Cristina   studied history\nProduct manager in payment in...
# Stephan    studied political science, history, currently ...
# Petra                grammar school teacher\nmarried, 3 kids
# Matic                                            Law, Single
# Natalija                            Artist, Married (Primož)
# Primož                         Architect, Married (Natalija)
# Nastja     English studies and philosophy\nWorks at an in...
# Börni           Working - Teamlead in despatching department
# Tereza               Workin within international business \n
# Nico                          Working  - Mechanical engineer
# Volker                                  buisnes unit manager
# Theresa                                              dentist
# Maria                            CEO charitable organisation
# Sofia                          studying in a dance programme
# Emma              Studying graphics and prints making (art)
# Lorenzo                           Studying Cultural Heritage
# Rocco      Master Strategy Entrepreneurship / Intern at B...
#
#                                    Q place of living place of living  \
# name
# Sabine                             Bad Bentheim, GER          abroad
# Jenny             from Salzburg, lives in Vienna, AT    Vienna based
# Britta        from Niederrhein, lives in Bayern, GER          abroad
# Lisa       from Bad Bentheim, living in Hamburg, GER          abroad
# Jaqueline         from Salzburg, lives in Vienna, AT    Vienna based
# Cristina    Romanian, living in Vienna for 10+ years    Vienna based
# Stephan                   Austrian, living in Vienna    Vienna based
# Petra                     Austrian, living in Vienna    Vienna based
# Matic                                       Slovenia          abroad
# Natalija                                      London          abroad
# Primož                                        London          abroad
# Nastja                                        Vienna    Vienna based
# Börni                                         Vienna    Vienna based
# Tereza                                      Scotland          abroad
# Nico                                        Scotland          abroad
# Volker                                 Upper Austria  outside Vienna
# Theresa                                Upper Austria  outside Vienna
# Maria                                         Vienna    Vienna based
# Sofia                                         Vienna    Vienna based
# Emma                                          Vienna    Vienna based
# Lorenzo                                 Italy (Alba)          abroad
# Rocco                                         Vienna    Vienna based
#
#                                        Q do you shop online? online shopping  \
# name
# Sabine     selten, wenn dann Lebensmittel, Festival & Mus...             Yes
# Jenny                                                    yes             Yes
# Britta                                                   yes             Yes
# Lisa                                                     yes             Yes
# Jaqueline                                                yes             Yes
# Cristina                                                 yes             Yes
# Stephan                                                  yes             Yes
# Petra                                                    yes             Yes
# Matic                                                    Yes             Yes
# Natalija                                           Partially             NaN
# Primož                                                   Yes             Yes
# Nastja                                                   Yes             Yes
# Börni                                                    Yes             Yes
# Tereza                                                   Yes             Yes
# Nico                                                     Yes             Yes
# Volker                                                   yes             Yes
# Theresa                                                  yes             Yes
# Maria                                                    yes             Yes
# Sofia                                                    yes             Yes
# Emma                                                     yes             Yes
# Lorenzo                                                  yes             Yes
# Rocco                                                    yes             Yes
#
#                                       Q why online shopping?  \
# name
# Sabine     I live in a town. Supermarket is around the co...
# Jenny                              It's just easy sometimes.
# Britta                                                   NaN
# Lisa                                                     NaN
# Jaqueline  Nice to ly in bed and to not need to go outsid...
# Cristina                              to buy clothes & books
# Stephan                                                  NaN
# Petra      more comfortable in some cases (dog food, heav...
# Matic      I don't like going to the store.\nFast search\...
# Natalija   Yes\nOverview\n\nNo\nI like to see, hold and t...
# Primož       Informed decision\nNo time pressure\nComparison
# Nastja     Avoid crowds\nOverview\nYou don't need to plan...
# Börni                        More convenient, less stressful
# Tereza                                  It's common standard
# Nico                                                    Fast
# Volker     prefers going to shops if possible \nbuys onli...
# Theresa                         but only big, trusted shops
# Maria                                                    NaN
# Sofia      Easier. Can compare prices with other shops. D...
# Emma            because I have trouble making fast decisions
# Lorenzo                              more choice and comfort
# Rocco      in Vienna more than Italy because everything c...
#
#                    why online shopping  ... apps - bad experinces  \
# name                                    ...
# Sabine                     convenience  ...                    no
# Jenny                      convenience  ...                   yes
# Britta                             NaN  ...                    no
# Lisa                               NaN  ...                   yes
# Jaqueline                  convenience  ...                    no
# Cristina                           NaN  ...                   NaN
# Stephan                            NaN  ...                   NaN
# Petra                convenience, time  ...                   NaN
# Matic      time, overview, convenience  ...                   NaN
# Natalija          overview, experiance  ...                   NaN
# Primož                  overview, time  ...                   NaN
# Nastja     convenience, overview, time  ...                   NaN
# Börni                      convenience  ...                    no
# Tereza                     convenience  ...                    no
# Nico                              time  ...                   yes
# Volker                             NaN  ...                   NaN
# Theresa                            NaN  ...                   NaN
# Maria                              NaN  ...                   NaN
# Sofia                      convenience  ...                   NaN
# Emma                              time  ...                   yes
# Lorenzo                       overview  ...                   yes
# Rocco                             time  ...                    no
#
#           Q Do you read all the information provided to you in a museum?\n[yes/no]  \
# name
# Sabine                                                    no
# Jenny                                                     no
# Britta                                                    no
# Lisa                                                      no
# Jaqueline                                         mostly not
# Cristina                                                  no
# Stephan                                                   no
# Petra                                                     no
# Matic                                                 Yes!\n
# Natalija                                             Depends
# Primož                                        Not everything
# Nastja                                               Usually
# Börni                                                     no
# Tereza                                                    no
# Nico                                                      no
# Volker     does not read much , \nonly very interessting ...
# Theresa                  reads a lot, \nprefers audio guides
# Maria                              depends, maybe half of it
# Sofia                                                    yes
# Emma                                                      no
# Lorenzo                                         usually yes
# Rocco                                                     no
#
#                           Q Why?\n[pain point / added value]  \
# name
# Sabine     Wenn ich alles lesen würde würde das viel zu l...
# Jenny      No, because it simply takes too long. Just the...
# Britta     because its always way too much text. She trie...
# Lisa       I only read what really interests me. Everythi...
# Jaqueline  Because of my backround I know a lot already.\...
# Cristina   no; especially if it's busy\n\nI always read t...
# Stephan    only reads the main attractions and what inter...
# Petra      techn.: read to children if not too difficult\...
# Matic                 Of course, I read all the information.
# Natalija   How much time I have. If I am in a hurry I tak...
# Primož                Too much information. I cherry-pick it
# Nastja     Because I don't have enough knowledge to know ...
# Börni                                                    NaN
# Tereza                                                   NaN
# Nico                                             added value
# Volker     no patience, must be paticulary interessting t...
# Theresa                                                  NaN
# Maria               depends on time, length of text, content
# Sofia      because most time I go with people that are sl...
# Emma       no large span of attention and i think i can a...
# Lorenzo    to understand the mental process of the creato...
# Rocco      because i get bored. But if is something that ...
#
#           Q Do you inform yourself about the content of the exhibition in advance?\n[yes/no]  \
# name
# Sabine                                                   yes
# Jenny                                                    yes
# Britta                                                   yes
# Lisa                                                     yes
# Jaqueline  I will read what the exhibit is about online a...
# Cristina   no, I read details on the spot, I don't like t...
# Stephan                                                   no
# Petra                                                     no
# Matic                   Yes, I always do the prior research.
# Natalija   Sometimes\n\nI always check the size of the ex...
# Primož                                                    No
# Nastja                                                   Yes
# Börni                                                    yes
# Tereza                                                   yes
# Nico                                                     yes
# Volker                                                    no
# Theresa                                                   no
# Maria                                                     no
# Sofia                           yes (but not super precisly)
# Emma                            yes (but not super precisly)
# Lorenzo                                                  yes
# Rocco                                                    yes
#
#           inform in advance  \
# name
# Sabine                  yes
# Jenny                   yes
# Britta                  yes
# Lisa                    yes
# Jaqueline               yes
# Cristina                 no
# Stephan                  no
# Petra                   NaN
# Matic                   yes
# Natalija                yes
# Primož                   no
# Nastja                  yes
# Börni                   yes
# Tereza                  yes
# Nico                    yes
# Volker                  NaN
# Theresa                 NaN
# Maria                   NaN
# Sofia                   yes
# Emma                    yes
# Lorenzo                 yes
# Rocco                   yes
#
#                      Q inform in advance - why? [motivation]  \
# name
# Sabine     --> Ich wohne auf dem Land, da gibts nicht so ...
# Jenny                 To make sure whether I like it or not.
# Britta     Regarding where and what is going on but she i...
# Lisa       I am always checking what to expect. to get so...
# Jaqueline                                                NaN
# Cristina   I read details on the spot, I don't like to sp...
# Stephan                                                  NaN
# Petra      no prior research, bc. lack of time\n\nusually...
# Matic        Because I want to know the context really well.
# Natalija   Mostly to make sure what is exhibited, if I al...
# Primož                                                   NaN
# Nastja     Only to inform myself about the exhibition but...
# Börni                          Otherwise I wouldn't go there
# Tereza                                       It motivates me
# Nico       Because than I will get insight what the event...
# Volker                                                   NaN
# Theresa                                                  NaN
# Maria                                                    NaN
# Sofia      because if I have to read everything I dont ha...
# Emma               not to spoil anything from the exhibition
# Lorenzo                he wants to know what he is visiting
# Rocco      don't want to lose time and understand if it s...
#
#           Q do you have any suggestion for the App?\nWhat do you wish to have or need?  \
# name
# Sabine                                                   NaN
# Jenny      I would book more often online even if they wo...
# Britta     Show nishes (not only the biggest museums),\nt...
# Lisa       App should be short and have a good overview a...
# Jaqueline  A Map would be nice to estimate whether you ca...
# Cristina   Would you consider an app that's a hub for mus...
# Stephan                                                  NaN
# Petra                                                    NaN
# Matic                                                 Filter
# Natalija   Size of exhibition\n\nDistance between exhibit...
# Primož                                                   NaN
# Nastja     Everything in one place\nSome kind of reminder...
# Börni                                                    Yes
# Tereza                                                   Yes
# Nico                                                     Yes
# Volker                                                   NaN
# Theresa                                                  NaN
# Maria                                                    NaN
# Sofia                                                    NaN
# Emma       Must have suggestions for the APP: 1. structur...
# Lorenzo    app related to culture (google arts and cultur...
# Rocco      filters for what you like or not, link to some...
#
#                                                  suggestions  \
# name
# Sabine                                                   NaN
# Jenny                                           audio guides
# Britta                                 favorits/filters, map
# Lisa                                                     NaN
# Jaqueline                                                map
# Cristina                                                 NaN
# Stephan                                                  NaN
# Petra                                                    NaN
# Matic                                                 filter
# Natalija                            map, favorites, previews
# Primož                                                   NaN
# Nastja                                    reminders, filters
# Börni                                               favorits
# Tereza                            personalised notifications
# Nico                     personalised notifications, preview
# Volker                                                   NaN
# Theresa                                                  NaN
# Maria                                                    NaN
# Sofia                                                    NaN
# Emma                                                     NaN
# Lorenzo    favorites for museums and have notification on...
# Rocco                                                    NaN
#
#                                          Unnamed: 57  \
# name
# Sabine                                           NaN
# Jenny                                            NaN
# Britta                                           NaN
# Lisa                                             NaN
# Jaqueline                                        NaN
# Cristina                                         NaN
# Stephan                                          NaN
# Petra                                            NaN
# Matic                                            NaN
# Natalija                                         NaN
# Primož                                           NaN
# Nastja                                           NaN
# Börni                                            NaN
# Tereza                                           NaN
# Nico                                             NaN
# Volker                                           NaN
# Theresa                                          NaN
# Maria                                            NaN
# Sofia                                            NaN
# Emma                                             NaN
# Lorenzo                                          NaN
# Rocco      He would buy it online if it was cheaper
#
#                          Unnamed: 58
# name
# Sabine                           NaN
# Jenny                            NaN
# Britta                           NaN
# Lisa                             NaN
# Jaqueline                        NaN
# Cristina                         NaN
# Stephan                          NaN
# Petra                            NaN
# Matic                            NaN
# Natalija                         NaN
# Primož                           NaN
# Nastja                           NaN
# Börni                            NaN
# Tereza                           NaN
# Nico                             NaN
# Volker                           NaN
# Theresa                          NaN
# Maria                            NaN
# Sofia                            NaN
# Emma                             NaN
# Lorenzo                          NaN
# Rocco      he is not keeping tickets
#
# [22 rows x 58 columns]

# %%
tags = data.drop([c for c in data.columns if c.startswith("Q") or c.startswith("Unnamed") or c == "vistits ranks"] , axis=1)
tags.columns
# Out:
# Index(['interviewer', 'age ranks', 'place of living', 'online shopping',
#        'why online shopping', 'display size', 'display - motives',
#        'visits museum', 'motives for museum visit',
#        'motivation for museum visit', 'vistits per year', 'kind of interrest',
#        'popularity', 'company', 'motives for company', 'information mode',
#        'information type', 'information challenges', 'would use app',
#        'ticket purchase', 'ticket purchase - motivation', 'uses app website',
#        'app used now', 'apps - bad experinces', 'inform in advance',
#        'suggestions'],
#       dtype='object')

# %%
def clean(x):
    if type(x) == list:
        return x[0]

    if pd.isna(x):
        return ""

    if pd.api.types.is_numeric_dtype(x):
        return x

    l = x.split(",")
    l = [i.strip() for i in l]
    l = sorted(l)
    s = ", ".join(l)
    return s.lower()

for column in tags:
    if pd.api.types.is_string_dtype(tags[column]):
        tags[column] = tags[column].apply(clean)

# %%
tags = tags.drop(columns=["online shopping"])

combinations = itertools.combinations(list(tags.columns), 2)
correlations = pd.DataFrame(0, index=tags.columns, columns=tags.columns)

for i, j in combinations:
    cont = pd.crosstab(tags[i], tags[j])
    try:
        correlations[i][j] = round(chi2_contingency(cont)[1],1)
        correlations[j][i] = round(chi2_contingency(cont)[1],1)

    except ValueError:
        correlations[i][j] = 0


from matplotlib import rcParams

rcParams['figure.figsize'] = 15,15


plot = sns.heatmap(correlations, annot=True).set_title("Chi^2 tests for contingencys")
fig = plot.get_figure()
fig.savefig("chi2_heatmap.png")

# %%
tags = tags.drop(columns=["interviewer"])

# %% [markdown]
# # K Modes

# %%
from kmodes.kmodes import KModes
# Elbow curve to find optimal K
cost = []
K = range(1,7)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 7, verbose=1)
    kmode.fit_predict(tags)
    cost.append(kmode.cost_)

plt = sns.lineplot(K, cost)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 281.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 281.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 281.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 281.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 281.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 0, cost: 281.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 0, cost: 281.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1, cost: 248.0
# Run 1, iteration: 2/100, moves: 0, cost: 248.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 246.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 2, cost: 255.0
# Run 3, iteration: 2/100, moves: 1, cost: 255.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 3, cost: 248.0
# Run 4, iteration: 2/100, moves: 0, cost: 248.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 4, cost: 244.0
# Run 5, iteration: 2/100, moves: 0, cost: 244.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 2, cost: 246.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 0, cost: 246.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3, cost: 217.0
# Run 1, iteration: 2/100, moves: 1, cost: 216.0
# Run 1, iteration: 3/100, moves: 0, cost: 216.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1, cost: 244.0
# Run 2, iteration: 2/100, moves: 0, cost: 244.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 2, cost: 211.0
# Run 3, iteration: 2/100, moves: 0, cost: 211.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 5, cost: 225.0
# Run 4, iteration: 2/100, moves: 3, cost: 216.0
# Run 4, iteration: 3/100, moves: 2, cost: 209.0
# Run 4, iteration: 4/100, moves: 0, cost: 209.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 2, cost: 232.0
# Run 5, iteration: 2/100, moves: 3, cost: 218.0
# Run 5, iteration: 3/100, moves: 0, cost: 218.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 6, cost: 210.0
# Run 6, iteration: 2/100, moves: 1, cost: 208.0
# Run 6, iteration: 3/100, moves: 0, cost: 208.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 0, cost: 211.0
# Best run was number 6
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1, cost: 197.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2, cost: 199.0
# Run 2, iteration: 2/100, moves: 1, cost: 197.0
# Run 2, iteration: 3/100, moves: 0, cost: 197.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 3, cost: 229.0
# Run 3, iteration: 2/100, moves: 6, cost: 196.0
# Run 3, iteration: 3/100, moves: 0, cost: 196.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2, cost: 193.0
# Run 4, iteration: 2/100, moves: 0, cost: 193.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1, cost: 188.0
# Run 5, iteration: 2/100, moves: 0, cost: 188.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 7, cost: 199.0
# Run 6, iteration: 2/100, moves: 2, cost: 191.0
# Run 6, iteration: 3/100, moves: 2, cost: 187.0
# Run 6, iteration: 4/100, moves: 0, cost: 187.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 1, cost: 211.0
# Best run was number 6
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3, cost: 186.0
# Run 1, iteration: 2/100, moves: 0, cost: 186.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 197.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1, cost: 183.0
# Run 3, iteration: 2/100, moves: 0, cost: 183.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 3, cost: 210.0
# Run 4, iteration: 2/100, moves: 4, cost: 193.0
# Run 4, iteration: 3/100, moves: 0, cost: 193.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 182.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 0, cost: 206.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 3, cost: 194.0
# Run 7, iteration: 2/100, moves: 1, cost: 193.0
# Run 7, iteration: 3/100, moves: 0, cost: 193.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1, cost: 197.0
# Run 1, iteration: 2/100, moves: 0, cost: 197.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1, cost: 167.0
# Run 2, iteration: 2/100, moves: 0, cost: 167.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 183.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 175.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 5, cost: 181.0
# Run 5, iteration: 2/100, moves: 1, cost: 180.0
# Run 5, iteration: 3/100, moves: 0, cost: 180.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 2, cost: 171.0
# Run 6, iteration: 2/100, moves: 1, cost: 170.0
# Run 6, iteration: 3/100, moves: 0, cost: 170.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 1, cost: 170.0
# Run 7, iteration: 2/100, moves: 0, cost: 170.0
# Best run was number 2
# /home/josmos/.local/share/virtualenvs/cleanclinspire-GyWQaIpZ/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Building the model with 3 clusters
tags_clustered = tags.copy(deep=True)
kmode = KModes(n_clusters=3, init = "random", n_init = 7, verbose=1)
clusters = kmode.fit_predict(tags)
tags_clustered["cluster"] = clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2, cost: 234.0
# Run 1, iteration: 2/100, moves: 0, cost: 234.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 3, cost: 236.0
# Run 2, iteration: 2/100, moves: 0, cost: 236.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 5, cost: 219.0
# Run 3, iteration: 2/100, moves: 1, cost: 215.0
# Run 3, iteration: 3/100, moves: 0, cost: 215.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 4, cost: 216.0
# Run 4, iteration: 2/100, moves: 0, cost: 216.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 4, cost: 216.0
# Run 5, iteration: 2/100, moves: 0, cost: 216.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 2, cost: 222.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 0, cost: 239.0
# Best run was number 3

# %%
tags
# Out:
#           age ranks place of living          why online shopping display size  \
# name
# Sabine          >40          abroad                  convenience        large
# Jenny         21-30    vienna based                  convenience        large
# Britta        31-40          abroad                                    medium
# Lisa          21-30          abroad                                     small
# Jaqueline     21-30    vienna based                  convenience        large
# Cristina      31-40    vienna based                                     small
# Stephan       21-30    vienna based                                     large
# Petra           >40    vienna based            convenience, time        small
# Matic         21-30          abroad  convenience, overview, time        small
# Natalija      21-30          abroad         experiance, overview        large
# Primož        21-30          abroad               overview, time        large
# Nastja        21-30    vienna based  convenience, overview, time        large
# Börni         21-30    vienna based                  convenience        large
# Tereza        21-30          abroad                  convenience        small
# Nico          21-30          abroad                         time        small
# Volker          >40  outside vienna                                     small
# Theresa         >40  outside vienna                                     small
# Maria           >40    vienna based                                    medium
# Sofia         21-30    vienna based                  convenience        large
# Emma          21-30    vienna based                         time    ambiguous
# Lorenzo       21-30          abroad                     overview        small
# Rocco         21-30    vienna based                         time        large
#
#                        display - motives    visits museum  \
# name
# Sabine                       ease of use              yes
# Jenny              ease of use, mobility              yes
# Britta     app optimization, ease of use              yes
# Lisa          app optimization, mobility  on holidays yes
# Jaqueline          ease of use, mobility              yes
# Cristina                                              yes
# Stephan              ease of use, safety              yes
# Petra                                                 yes
# Matic
# Natalija
# Primož
# Nastja
# Börni                   app optimization              yes
# Tereza                          mobility              yes
# Nico                         ease of use              yes
# Volker                          mobility              yes
# Theresa                         mobility              yes
# Maria                           mobility              yes
# Sofia                                                 yes
# Emma                                                  yes
# Lorenzo                      ease of use              yes
# Rocco                ease of use, safety              yes
#
#                            motives for museum visit  \
# name
# Sabine                        creativity, education
# Jenny
# Britta                       creativity, relaxation
# Lisa                                      education
# Jaqueline                       education, interest
# Cristina                      creativity, education
# Stephan                                   education
# Petra                                     education
# Matic                           education, interest
# Natalija   creativity, interest, relaxation, social
# Primož                             interest, social
# Nastja                  education, interest, social
# Börni                                    creativity
# Tereza                                    education
# Nico                                     creativity
# Volker                                    education
# Theresa                                   education
# Maria                             education, social
# Sofia                                     education
# Emma                                      education
# Lorenzo                                   education
# Rocco                        creativity /relaxation
#
#           motivation for museum visit vistits per year     kind of interrest  \
# name
# Sabine                      intrinsic                4
# Jenny                       intrinsic                4
# Britta                      intrinsic                4
# Lisa                        intrinsic                1               history
# Jaqueline                   intrinsic               17  art, history, nature
# Cristina                    intrinsic               24
# Stephan                     intrinsic                4
# Petra                       extrinsic                2
# Matic                       intrinsic                                history
# Natalija                    intrinsic                                    art
# Primož                           both                                    art
# Nastja                           both                                    art
# Börni                                              1-2
# Tereza                                               ?
# Nico                                                 2
# Volker                      extrinsic                2         history, tech
# Theresa                     extrinsic                4               history
# Maria                       intrinsic               na                   art
# Sofia                       intrinsic               12                   art
# Emma                        intrinsic            40-48                   art
# Lorenzo                     intrinsic            40-48           art/history
# Rocco                       intrinsic                8
#
#            ...                                   information type  \
# name       ...
# Sabine     ...  billboards, newspaper, social media, word-of-m...
# Jenny      ...               museum website, other, word-of-mouth
# Britta     ...                                             google
# Lisa       ...                                              other
# Jaqueline  ...                              museum website, other
# Cristina   ...  google, museum website, other, social media, w...
# Stephan    ...  billboards, google, museum website, word-of-mouth
# Petra      ...                                      word-of-mouth
# Matic      ...          billboards, google, museum website, other
# Natalija   ...  google, museum website, other, social media, w...
# Primož     ...              google, museum website, word-of-mouth
# Nastja     ...  billboards, google, museum website, other, soc...
# Börni      ...                                      word-of-mouth
# Tereza     ...                                       social media
# Nico       ...                                     museum website
# Volker     ...                        media-reports, social media
# Theresa    ...                                other, social media
# Maria      ...  google, media-reports, social media, word-of-m...
# Sofia      ...                                       social media
# Emma       ...                          billboards, word-of-mouth
# Lorenzo    ...                             google, museum website
# Rocco      ...                                       social media
#
#                            information challenges would use app  \
# name
# Sabine                                                      yes
# Jenny                                                       yes
# Britta     no clarity, no clarity, time consuming           yes
# Lisa                                   no clarity           yes
# Jaqueline                              no clarity           yes
# Cristina                    scattered information           yes
# Stephan
# Petra
# Matic                                                       yes
# Natalija                    scattered information           yes
# Primož                                                      yes
# Nastja                      scattered information           yes
# Börni                                                       yes
# Tereza                                                      yes
# Nico            no clarity, scattered information           yes
# Volker
# Theresa
# Maria                    no clarity, no reminders
# Sofia                                                       yes
# Emma                                 no reminders           yes
# Lorenzo         no clarity, scattered information           yes
# Rocco                       scattered information           yes
#
#                                  ticket purchase  \
# name
# Sabine                            mostly offline
# Jenny                             mostly offline
# Britta                                   offline
# Lisa                                     offline
# Jaqueline                                offline
# Cristina   offline, online (price), subscription
# Stephan
# Petra
# Matic                                    offline
# Natalija                                    both
# Primož                                      both
# Nastja                                    museum
# Börni                                    offline
# Tereza                                    online
# Nico                                      online
# Volker
# Theresa
# Maria
# Sofia                            offline, online
# Emma                                     offline
# Lorenzo                                   online
# Rocco                                    offline
#
#                       ticket purchase - motivation uses app website  \
# name
# Sabine                                 flexibility               no
# Jenny                                  flexibility               no
# Britta                    flexibility, time saving               no
# Lisa                                   time saving              yes
# Jaqueline                              convenience              yes
# Cristina   collecting instinct, information, price              yes
# Stephan                                convenience               no
# Petra                                                            no
# Matic                                  convenience
# Natalija                  convenience, time saving
# Primož                          convenience, price
# Nastja                                 convenience
# Börni                                  time saving               no
# Tereza                                 time saving               no
# Nico                      convenience, time saving               no
# Volker                                                           no
# Theresa                                                          no
# Maria                                                            no
# Sofia                                                           yes
# Emma                                   flexibility              yes
# Lorenzo                                time saving              yes
# Rocco                                  flexibility              yes
#
#                              app used now apps - bad experinces  \
# name
# Sabine                                                       no
# Jenny                                                       yes
# Britta                                                       no
# Lisa                          google maps                   yes
# Jaqueline                                                    no
# Cristina               google\nmuseum app
# Stephan                google, is invited
# Petra                          is invited
# Matic
# Natalija                      tripadvisor
# Primož
# Nastja                              inspi
# Börni                                                        no
# Tereza                                                       no
# Nico                                                        yes
# Volker
# Theresa
# Maria
# Sofia                   instagram, google
# Emma                              esel.at                   yes
# Lorenzo    arte.it, google arts & culture                   yes
# Rocco                            facebook                    no
#
#           inform in advance                                        suggestions
# name
# Sabine                  yes
# Jenny                   yes                                       audio guides
# Britta                  yes                              favorits/filters, map
# Lisa                    yes
# Jaqueline               yes                                                map
# Cristina                 no
# Stephan                  no
# Petra
# Matic                   yes                                             filter
# Natalija                yes                           favorites, map, previews
# Primož                   no
# Nastja                  yes                                 filters, reminders
# Börni                   yes                                           favorits
# Tereza                  yes                         personalised notifications
# Nico                    yes                personalised notifications, preview
# Volker
# Theresa
# Maria
# Sofia                   yes
# Emma                    yes
# Lorenzo                 yes  favorites for museums and have notification on...
# Rocco                   yes
#
# [22 rows x 24 columns]

# %%
import pandas as pd, numpy as np
from emperor import Emperor, nbinstall
from skbio import OrdinationResults
import prince

nbinstall()

def load_mf(fn, index='#SampleID'):
    _df = pd.read_csv(fn, sep='\t', dtype=str, keep_default_na=False, na_values=[])
    _df.set_index(index, inplace=True)
    return _df

# %%
import prince
mca = prince.MCA(
    n_components=22,
    n_iter=7,
    copy=True,
    check_input=True,
    engine='auto',
    random_state=42
    )
mca = mca.fit(tags_clustered)
mca.row_coordinates(tags_clustered).index = tags_clustered.index

# %%
mca.eigenvalues_
# Out:
# array([0.27695509, 0.20651021, 0.1362608 , 0.12164312, 0.09195111,
#        0.08539064, 0.076681  , 0.0625991 , 0.05077057, 0.04879632,
#        0.04831623, 0.04138123, 0.03532342, 0.02986922, 0.02643074,
#        0.02544096, 0.02158332, 0.01705672, 0.01039569, 0.0066732 ,
#        0.00162901, 0.        ])

# %%
ax = mca.plot_coordinates(
    X=tags_clustered,
    ax=None,
    figsize=(15, 15),
    x_component=0,
    y_component=1,
    show_row_points=True,
    row_points_size=40,
    show_row_labels=True,
    show_column_points=True,
    column_points_size=30,
    show_column_labels=False,
    legend_n_cols=1,
    row_groups=list(tags_clustered["cluster"])
    )
ax.get_figure().savefig('mca_coordinates.svg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 ax = mca.plot_coordinates(
#       2     X=tags_clustered,
#       3     ax=None,
#       4     figsize=(15, 15),
#       5     x_component=0,
#       6     y_component=1,
#       7     show_row_points=True,
#       8     row_points_size=40,
#       9     show_row_labels=True,
#      10     show_column_points=True,
#      11     column_points_size=30,
#      12     show_column_labels=False,
#      13     legend_n_cols=1,
#      14     row_groups=list(tags_clustered["cluster"])
#      15     )
#      16 ax.get_figure().savefig('mca_coordinates.svg')
#
# File ~/.local/share/virtualenvs/cleanclinspire-GyWQaIpZ/lib/python3.9/site-packages/prince/mca.py:177, in MCA.plot_coordinates(self, X, ax, figsize, x_component, y_component, show_row_points, row_points_size, row_points_alpha, row_groups, show_row_labels, show_column_points, column_points_size, show_column_labels, legend_n_cols)
#     174 x = col_coords[x_component]
#     175 y = col_coords[y_component]
# --> 177 prefixes = col_coords.index.str.split('_').map(lambda x: x[0])
#     179 for prefix in prefixes.unique():
#     180     mask = prefixes == prefix
#
# File ~/.local/share/virtualenvs/cleanclinspire-GyWQaIpZ/lib/python3.9/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/.local/share/virtualenvs/cleanclinspire-GyWQaIpZ/lib/python3.9/site-packages/pandas/core/strings/accessor.py:177, in StringMethods.__init__(self, data)
#     174 def __init__(self, data):
#     175     from pandas.core.arrays.string_ import StringDtype
# --> 177     self._inferred_dtype = self._validate(data)
#     178     self._is_categorical = is_categorical_dtype(data.dtype)
#     179     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/.local/share/virtualenvs/cleanclinspire-GyWQaIpZ/lib/python3.9/site-packages/pandas/core/strings/accessor.py:231, in StringMethods._validate(data)
#     228 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     230 if inferred_dtype not in allowed_types:
# --> 231     raise AttributeError("Can only use .str accessor with string values!")
#     232 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
tags_clustered
# Out:
#           age ranks place of living          why online shopping display size  \
# name
# Sabine          >40          abroad                  convenience        large
# Jenny         21-30    vienna based                  convenience        large
# Britta        31-40          abroad                                    medium
# Lisa          21-30          abroad                                     small
# Jaqueline     21-30    vienna based                  convenience        large
# Cristina      31-40    vienna based                                     small
# Stephan       21-30    vienna based                                     large
# Petra           >40    vienna based            convenience, time        small
# Matic         21-30          abroad  convenience, overview, time        small
# Natalija      21-30          abroad         experiance, overview        large
# Primož        21-30          abroad               overview, time        large
# Nastja        21-30    vienna based  convenience, overview, time        large
# Börni         21-30    vienna based                  convenience        large
# Tereza        21-30          abroad                  convenience        small
# Nico          21-30          abroad                         time        small
# Volker          >40  outside vienna                                     small
# Theresa         >40  outside vienna                                     small
# Maria           >40    vienna based                                    medium
# Sofia         21-30    vienna based                  convenience        large
# Emma          21-30    vienna based                         time    ambiguous
# Lorenzo       21-30          abroad                     overview        small
# Rocco         21-30    vienna based                         time        large
#
#                        display - motives    visits museum  \
# name
# Sabine                       ease of use              yes
# Jenny              ease of use, mobility              yes
# Britta     app optimization, ease of use              yes
# Lisa          app optimization, mobility  on holidays yes
# Jaqueline          ease of use, mobility              yes
# Cristina                                              yes
# Stephan              ease of use, safety              yes
# Petra                                                 yes
# Matic
# Natalija
# Primož
# Nastja
# Börni                   app optimization              yes
# Tereza                          mobility              yes
# Nico                         ease of use              yes
# Volker                          mobility              yes
# Theresa                         mobility              yes
# Maria                           mobility              yes
# Sofia                                                 yes
# Emma                                                  yes
# Lorenzo                      ease of use              yes
# Rocco                ease of use, safety              yes
#
#                            motives for museum visit  \
# name
# Sabine                        creativity, education
# Jenny
# Britta                       creativity, relaxation
# Lisa                                      education
# Jaqueline                       education, interest
# Cristina                      creativity, education
# Stephan                                   education
# Petra                                     education
# Matic                           education, interest
# Natalija   creativity, interest, relaxation, social
# Primož                             interest, social
# Nastja                  education, interest, social
# Börni                                    creativity
# Tereza                                    education
# Nico                                     creativity
# Volker                                    education
# Theresa                                   education
# Maria                             education, social
# Sofia                                     education
# Emma                                      education
# Lorenzo                                   education
# Rocco                        creativity /relaxation
#
#           motivation for museum visit vistits per year     kind of interrest  \
# name
# Sabine                      intrinsic                4
# Jenny                       intrinsic                4
# Britta                      intrinsic                4
# Lisa                        intrinsic                1               history
# Jaqueline                   intrinsic               17  art, history, nature
# Cristina                    intrinsic               24
# Stephan                     intrinsic                4
# Petra                       extrinsic                2
# Matic                       intrinsic                                history
# Natalija                    intrinsic                                    art
# Primož                           both                                    art
# Nastja                           both                                    art
# Börni                                              1-2
# Tereza                                               ?
# Nico                                                 2
# Volker                      extrinsic                2         history, tech
# Theresa                     extrinsic                4               history
# Maria                       intrinsic               na                   art
# Sofia                       intrinsic               12                   art
# Emma                        intrinsic            40-48                   art
# Lorenzo                     intrinsic            40-48           art/history
# Rocco                       intrinsic                8
#
#            ...                  information challenges would use app  \
# name       ...
# Sabine     ...                                                   yes
# Jenny      ...                                                   yes
# Britta     ...  no clarity, no clarity, time consuming           yes
# Lisa       ...                              no clarity           yes
# Jaqueline  ...                              no clarity           yes
# Cristina   ...                   scattered information           yes
# Stephan    ...
# Petra      ...
# Matic      ...                                                   yes
# Natalija   ...                   scattered information           yes
# Primož     ...                                                   yes
# Nastja     ...                   scattered information           yes
# Börni      ...                                                   yes
# Tereza     ...                                                   yes
# Nico       ...       no clarity, scattered information           yes
# Volker     ...
# Theresa    ...
# Maria      ...                no clarity, no reminders
# Sofia      ...                                                   yes
# Emma       ...                            no reminders           yes
# Lorenzo    ...       no clarity, scattered information           yes
# Rocco      ...                   scattered information           yes
#
#                                  ticket purchase  \
# name
# Sabine                            mostly offline
# Jenny                             mostly offline
# Britta                                   offline
# Lisa                                     offline
# Jaqueline                                offline
# Cristina   offline, online (price), subscription
# Stephan
# Petra
# Matic                                    offline
# Natalija                                    both
# Primož                                      both
# Nastja                                    museum
# Börni                                    offline
# Tereza                                    online
# Nico                                      online
# Volker
# Theresa
# Maria
# Sofia                            offline, online
# Emma                                     offline
# Lorenzo                                   online
# Rocco                                    offline
#
#                       ticket purchase - motivation uses app website  \
# name
# Sabine                                 flexibility               no
# Jenny                                  flexibility               no
# Britta                    flexibility, time saving               no
# Lisa                                   time saving              yes
# Jaqueline                              convenience              yes
# Cristina   collecting instinct, information, price              yes
# Stephan                                convenience               no
# Petra                                                            no
# Matic                                  convenience
# Natalija                  convenience, time saving
# Primož                          convenience, price
# Nastja                                 convenience
# Börni                                  time saving               no
# Tereza                                 time saving               no
# Nico                      convenience, time saving               no
# Volker                                                           no
# Theresa                                                          no
# Maria                                                            no
# Sofia                                                           yes
# Emma                                   flexibility              yes
# Lorenzo                                time saving              yes
# Rocco                                  flexibility              yes
#
#                              app used now apps - bad experinces  \
# name
# Sabine                                                       no
# Jenny                                                       yes
# Britta                                                       no
# Lisa                          google maps                   yes
# Jaqueline                                                    no
# Cristina               google\nmuseum app
# Stephan                google, is invited
# Petra                          is invited
# Matic
# Natalija                      tripadvisor
# Primož
# Nastja                              inspi
# Börni                                                        no
# Tereza                                                       no
# Nico                                                        yes
# Volker
# Theresa
# Maria
# Sofia                   instagram, google
# Emma                              esel.at                   yes
# Lorenzo    arte.it, google arts & culture                   yes
# Rocco                            facebook                    no
#
#           inform in advance  \
# name
# Sabine                  yes
# Jenny                   yes
# Britta                  yes
# Lisa                    yes
# Jaqueline               yes
# Cristina                 no
# Stephan                  no
# Petra
# Matic                   yes
# Natalija                yes
# Primož                   no
# Nastja                  yes
# Börni                   yes
# Tereza                  yes
# Nico                    yes
# Volker
# Theresa
# Maria
# Sofia                   yes
# Emma                    yes
# Lorenzo                 yes
# Rocco                   yes
#
#                                                  suggestions cluster
# name
# Sabine                                                             2
# Jenny                                           audio guides       2
# Britta                                 favorits/filters, map       2
# Lisa                                                               0
# Jaqueline                                                map       2
# Cristina                                                           0
# Stephan                                                            2
# Petra                                                              1
# Matic                                                 filter       0
# Natalija                            favorites, map, previews       0
# Primož                                                             0
# Nastja                                    filters, reminders       2
# Börni                                               favorits       2
# Tereza                            personalised notifications       2
# Nico                     personalised notifications, preview       0
# Volker                                                             1
# Theresa                                                            1
# Maria                                                              1
# Sofia                                                              0
# Emma                                                               0
# Lorenzo    favorites for museums and have notification on...       0
# Rocco                                                              2
#
# [22 rows x 25 columns]

# %%
len(tags_clustered["cluster"])
# Out:
# 22

# %%
coords = mca.row_coordinates(tags_clustered)
coords.columns = [col +1 for col in coords.columns]
coords.index = tags_clustered.index

# %%
coords.to_csv("coords.tsv", sep="\t")

# %%
with open("ord.tsv", "w") as fh:
    samples = len(mca.eigenvalues_)
    fh.write(f"Eigvals\t{samples}\n")
    fh.write("\t".join([str(e) for e in mca.eigenvalues_]) + "\n\n")
    fh.write(f"Proportion explained\t{samples}\n")
    fh.write("\t".join([str(e) for e in mca.explained_inertia_]) + "\n\n")
    fh.write("Species\t0\t0\n\n")
    fh.write(f"Site\t{samples}\t{samples}")
    fh.write("\n")
    with open("coords.tsv", "r") as co:
        co.readline()
        cont = co.read()
        fh.write(cont)
    fh.write("\nBiplot\t0\t0\n\nSite constraints\t0\t0")

# %%
from emperor import Emperor
from os import makedirs
from os.path import join
from skbio import OrdinationResults

ordination = OrdinationResults.read('ord.tsv')

# the remote argument refers to where the support files will be located
# relative to the plot itself i.e. index.html.
emp = Emperor(ordination, tags_clustered, remote='.')
output_folder = 'plot' # new folder where data will be saved

# create an output directory
makedirs(output_folder, exist_ok=True)

with open(join(output_folder, 'index.html'), 'w') as f:
    f.write(emp.make_emperor(standalone=True))
    emp.copy_support_files(output_folder)

# %%
from IPython.lib.display import IFrame
import os
os.chdir("/plot/")
IFrame("plot/index.html", width=600, height=400)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [33], in <cell line: 3>()
#       1 from IPython.lib.display import IFrame
#       2 import os
# ----> 3 os.chdir("/plot/")
#       4 IFrame("plot/index.html", width=600, height=400)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/plot/'
